# %%
import pandas as pd
import json
import requests
import itertools
import xml.etree.ElementTree as ET
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
url = 'https://www.mobis-as.com/faqLoad.do?pageIndex=1&categoryId=ALL'
response = requests.get(url, verify=False)
if response.status_code == 200:
    questions_list = []

    for page in range(1, 5):
        url = f'https://www.mobis-as.com/faqLoad.do?pageIndex={page}&categoryId=ALL'
        response = requests.get(url, verify=False)
        bs = BeautifulSoup(response.text, 'lxml')
        
        # List comprehension을 사용하여 질문 텍스트 추출
        questions = [question.text for question in bs.select('ul.faq-list li button.tit span')]
        
        # 추출한 질문들을 questions_list에 추가
        questions_list.extend(questions)

questions_list
# Out:
# ['직영판매점이나 대리점 위치를 알고 싶어요',
#  'WPC 접속을 어떻게 하나요?',
#  'WPC 회원가입 및 탈퇴는 어떻게 하나요?',
#  '현대자동차그룹을 사칭하여 각종 부품을 판매합니다.',
#  '현대모비스 고객센터는 어떻게 운영되나요?',
#  '현대카드 M포인트로 대금결제가 가능한가요?',
#  '현대오토넷을 사칭하여 상품을 판매합니다.',
#  '내비게이션(AVN:오디오 · 비디오 · 내비게이션) 업데이트는 어떻게 하나요?',
#  '현대모비스의 채용관련 사항 및 원서접수는 어디서 하나요?',
#  '순정부품 품질보증기간에 대해 알려주십시오.',
#  '순정부품과 KS규격부품은 서로 다른가요?',
#  '모비스 부품대리점과 직영판매점(사업소) 간에 부품 가격이 다를 수 있나요?',
#  'WPC에서 부품 조회시 \'Part list\'에 수량이 "2","3" 과 같이 표시된 부품의 가격은 낱개인가요?',
#  'WPC가 제 컴퓨터에서 실행되지 않는데 어떻게 하나요?',
#  'WPC에서 부품번호 확인을 했는데 부품가격이 없는 경우, 어떻게 합니까?',
#  '차량 등록 시 이미 등록된 차량번호라는 안내와 함께 등록이 안 될 때 어떻게 하나요?',
#  '회원 가입시 등록된 차량 이외의 다른 옵션 부품이나 다른 차량 부품검색은 어떻게 하나요?',
#  '교환/반품은 어떻게 진행 됩니까?',
#  '할로겐램프는 어떻게 교환합니까?',
#  'i3000+는 어떻게 사용합니까?',
#  ' i3000+를 휘발유용 경유차에 넣었습니다. 어떻게 해야 할까요?',
#  'i3000+는 얼마마다 사용하는 것이 좋습니까?',
#  '오토삭(AutoSock) 주의사항을 알려주십시오.',
#  ' 오토삭(AutoSock) 사용방법을 알려주십시오.',
#  '플랫와이퍼에서 떨림 또는 소음이 발생합니다.',
#  '플랫와이퍼 닦임성능 저하되었습니다. 어떻게 해야합니까?',
#  '순정용품 품질보증기간에 대해 알려주십시오.',
#  '경로를 우회거나 카메라 안내가 너무 느립니다. 제품 불량인가요?',
#  '신규 휴대폰 등록을 어떻게 하나요?',
#  '전화번호부는 어떻게 사용하나요?',
#  'AV 헤드유닛 주요 기능은 어떤 것들이 있으며, 어떻게 사용해야 하나요?',
#  '블루링크/UVO 개통은 어떻게 하며, 어떤 기능이 있나요?',
#  'CD 재생이 되지 않습니다. 제품 불량인가요?',
#  '주행 중 라디오 청취 시 노이즈가 발생합니다. 제품 불량인가요?',
#  'DMB 수신이 안됩니다. 제품 불량인가요?',
#  '제품 동작 중 일시적으로 이상이 발생하여 작동되지 않습니다, 어떻게 해야 하나요?']

# %%
url = 'https://www.mobis-as.com/faqLoad.do?pageIndex=1&categoryId=ALL'
response = requests.get(url, verify=False)
if response.status_code == 200:
    answers_list = []

    for page in range(1, 5):
        url = f'https://www.mobis-as.com/faqLoad.do?pageIndex={page}&categoryId=ALL'
        response = requests.get(url, verify=False)
        bs = BeautifulSoup(response.text, 'lxml')
        
        # List comprehension을 사용하여 답변 텍스트 추출
        answers = [answer.text for answer in bs.select('ul.faq-list div.txt')]
        
        # 추출한 질문들을 answers_list에 추가
        answers_list.extend(answers)

answers_list
# Out:
# ['직영판매점 및 부품대리점 위치는 현대모비스(https://www.mobis-as.com)\xa0홈페이지의 "A/S부품 > 판매 지점 검색" 메뉴에서 확인하실 수 있습니다.',
#  'WPC는 현대모비스 홈페이지 "A/S부품> 부품상세검색" 메뉴를 통해 접속 가능하며 합니다. \xa0해당 기능은 회원에 한해 이용이 가능하기 때문에 회원 가입\xa0후 로그인하여 이용하시길 바랍니다.\xa0\xa0',
#  '1. 홈페이지 내 A/S부품> 부품상세검색 메뉴에서 회원가입 버튼을 통해 가입하실 수 있습니다.2. 탈퇴의 경우 로그인된 상태에서 A/S부품> 부품상세검색 메뉴의 회원탈퇴 버튼을 통해 진행 하실 수 있습니다.',
#  '최근 현대자동차그룹(현대,기아,모비스)을 사칭하여 정품이 아닌 사제품을, 심지어 미취급 품목까지도, 고객에게 현대차그룹이 판매하는 것처럼 속여 피해를 주는 사례들이 자주 있습니다. 현대자동차 및 기아자동차는 완성차 메이커로서 자동차 부품이나 용품 판매를 하지 않으며, 당사 현대모비스의 경우에도 가두판매나 방문판매 형태의 영업행위는 행하지 않사오니, 고객님께서 판매자의 신분이 의심스러운 물품의 구매제의를 받으실 경우 반드시 당사 현대모비스 부품상담센터(1588-7278)로 확인바랍니다.',
#  '저희 현대모비스는 고객님의 편의를 위해 고객센터를 운영하고 있으며,유선상담시간은 아래와 같습니다.ㆍ대표번호 : 1588-7278ㆍ고객센터 운영시간\xa0 \xa0 \xa0ㆍ평 일 : 08:30 ~ 18:00 (중식시간 : 12:00 ~ 13:00)\xa0 \xa0 \xa0ㆍ토요일 : 09:00 ~ 12:00\xa0 \xa0 \xa0ㆍ일요일/공휴일 : 휴무',
#  '부품 구매시 현대 M카드 포인트 사용은 지원되고 있지 않습니다.',
#  '최근 현대오토넷을 사칭하여 내비게이션 등 멀티미디어관련 상품을 판매하는 사례가 접수되고 있습니다. 현대오토넷은 2009년 6월 25일부로 당사 현대모비스에 흡수합병되었으며, 당사는 전화판매나 방문판매를 행하지 않사오니, 고객님께서 판매자의 신분이 의심스러운 물품의 구매제의를 받으실 경우 반드시 당사 고객센터(1588-7278)로 사전에 확인하시기 바랍니다.',
#  '내비게이션 업데이트 관련 안내는 현대모비스 A/S부품·용품 사이트\xa0"멀티제품 > 내비게이션 업데이트" 메뉴를 통해확인 가능합니다. 고객님의 보유 차종 및 AVN 모델에 따라 각각의 "바로가기" 를 통해 연결되는 웹사이트에서상세 안내 확인 및 업데이트를 진행할 수 있습니다.',
#  '보다 자세한 채용안내, 모집공고 및 원서접수 등은 현대모비스의 아래의 채용사이트를 방문해 주시기 바랍니다.\xa0https://mobis.recruiter.co.kr/',
#  '장착일로부터 1년이며, 2만km입니다(단, 소모품의 경우 교환주기가 미도달한 상태에서 6개월, 1만km).',
#  '순정부품과 KS규격부품은 모두 인증제품이라는 면에서는 서로 같습니다\xa0그러나 KS규격부품은 정부인증제품이며, 순정부품은 메이커 인증제품입니다.\xa0▶ KS규격부품 : 개별 부품단위의 표준화된 인증규격을 만족하는 부품입니다.\xa0▶ 순정부품 : 순정부품이란, 현대자동차와 기아자동차의 제조, 생산시 조립되는 것과\xa0동일한 부품으로서 철저한 품질검사 및 엄격한 테스트를 통해 생산되었습니다. 개별 부품에 대한 성능뿐만 아니라 차에 장착했을 때 다른 부품과의 연계성을 최대한 감안하여 인증된 부품입니다\xa0',
#  "WPC상의 가격은 공임이 포함되지 않은 부가가치세가 포함된 소비자 가격입니다.\xa0즉, 모비스 직영부품 사업장(직영판매점)에서 구입하실 때 받는 가격입니다\xa0다만, 대리점이 직영판매점과 동일가격으로 판매 여부는 해당 대리점 자율에 맡겨져 있습니다.\xa0'독점 및 공정거래에 관한 법률'에 의거하여 모비스는 대리점에게 소비자 가격을 강제하지 않고 있습니다\xa0",
#  "WPC를 통해 부품을 조회했을 때 \xa0'PartList'의 나타나는 수량은 해당 부품 교체시 필요한 총 수량이며, 표기된 부품가격은 총 수량의 가격이 아닌 1개당 판매가격 입니다.\xa0",
#  'WPC 창이 팝업타입으로 뜨지 않는 경우,고객님 PC에 팝업차단이 설정되어 있는지 먼저 확인바랍니다\xa0그리고 WPC는 웹 서버이기 때문에 간헐적으로 불안정할 수 있으며,\xa0사용자 폭주로 일시적으로 원활하지 않을 수도 있습니다.\xa0이처럼 WPC 실행 후 원활한 검색이 이뤄지지 않을 때에는 바로 당사 고객센터(1588-7278)로 문의 바랍니다.',
#  '부품가격이 제외된 부품의 경우 번거로우시겠지만 당사 고객센터(1588-7278)로 문의 바랍니다.',
#  '이런 경우는 대개 중고차량으로 이전 차주가 먼저 홈페이지 등록 상태에서 차량을 판매하여 회원정보가 이전 차주 명의로 되어 있거나, 정비 공장에서 부품 조회를 위해 차대번호를 입력한 뒤 차대번호를 지우지 않아 발생됩니다. 번거로우시더라도 차량등록증 및 신분증(등록증상 차주신분증) 사본 확인 후 고객센터(1588-7278)로 문의 바랍니다.',
#  '회사 정책상 회원 가입시 입력한 차대번호 차량에 대해서만 부품검색이 될 수 있습니다(최대 5대까지 입력가능).\xa0이는 AS부품 특성상 고객님의 소지하시는 차량에 장착된 부품만을 찾기 위한 조치입니다.',
#  '1. 장착 전 : 구입하신 부품에 이상이 있을 경우 구입일로부터 60일 이내\xa0구매 영수증을 지참하시면 구매처에서\xa0교환 또는 환불해 드립니다.\xa02. 장착 후 : 구입하신 부품이 순정부품(자기 차량에 맞는 부품)이고, 정비업체를 통해 정비하신 경우 클레임 규정에 의하여 처리해 드립니다.\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0단, 자가 정비로 인한 클레임 발생시 보증하지 않습니다.3. 차량과 맞지 않는 부품을 사용하셨을 경우 클레임처리가 불가능합니다(예: 튜닝 등).',
#  '다음과 같은 방법으로 교환하세요.\xa0① 전구는 한쌍으로 교환 하세요.\xa0② 매 50,000km 주행 또는 매 2년마다 전조등 전구를 교환하세요.\xa0③ 눈부심 현상을 막기 위해 모든 등을 정기적으로 조정하세요.\xa0④ 비상시를 대비하여 항상 예비품을 준비하세요.',
#  '간단히 연료탱크에 기름을 넣기 전에 미리 넣고, 기름을 가득 채워주면 골고루 섞일 수 있어서 좋습니다.',
#  '문제없습니다. 본 제품은 기본적인 성분은 휘발유용과 경유용이 같습니다. 유종의 특성에 따라 조합비율이 조금 다를 뿐이기 때문에 아무 문제가 없습니다. 다만 효과가 조금 떨어질 수 있습니다.\xa0',
#  '한번 넣으면 5,000km까지 효과가 지속 됩니다. 5,000km 마다 정기적으로 넣어 주면 항상 엔진 상태를 깨끗하게 유지할 수 있어서 좋습니다. 그런데 i3000+를 처음사용하시는 경우에는 그동안 카본때가 많이 끼어 있을 수 있기 때문에 500ml 한 병을 모두 주입하시거나, 1/3씩 3회 연속 주입하여 사용하면 빠른 효과를 보실 수 있습니다.\xa0',
#  '스노우체인 오토삭제품은 빙판길 긴급구난 제품입니다. 아래사항을 반드시 지켜주십시오.\xa0① 반드시 타이어 사이즈에 맞는 제품을 사용해주세요(제품규격표 참조).\xa0② 주차 시에는 반드시 제품을 탈거해 주세요.\xa0③ 일반건조 아스팔트/콘크리트 노면이나 오프로드 환경에서는 제품이 단시간에도 심각하게 손상 될 수 있어 사용이 불가합니다.\xa0④ 사용과정에서 제품 표면에 구멍이나 부분적으로 찢어진 부위가 생길 수 있으나, 이는 마모과정에서 발생하는 자연스런 현상으로 기능에는 전혀 문제가 없습니다.\xa0⑤ 제품이 장착이 불가능 할 정도로 완전히 헤어지거나 제품안쪽 검은색 부분이 밖으로 노출되면 사용한도에 도달한 것입니다. 새 제품으로 교환해주세요.\xa0⑥ 제품 장착 후에도 세심한 주의를 기울여 최대한 저속으로 안전 운전하시고, 어떠한 경우에도 시속 50km 이상 주행하지 마세요.\xa0⑦ 오토삭 장착사용 시 차량 앞 뒤축간에는 상당한 노면마찰력의 차이가 발생하기 때문에 장착하지 않은 축은 접지력이 순간적으로 저하될 위험이 있습니다.\xa0',
#  '1. 장착 전\xa0장착전 반드시 타이어사이즈와 제품 사이즈를 확인하시기 바랍니다.\xa02. 장착\xa0① 차를 정지시키고 핸드브레이크를 채워주세요.\xa0② 오토삭을 구동바퀴에 장착해 주세요.\xa0③ 타이어의 상부부터 아래쪽으로 씌워주세요.\xa0④ 차를 1m가량 움직이고 남은 부분도 마찬가지로 씌워주세요.\xa0⑤ 주행을 시작하면 자동적으로 중심을 찾고 제위치를 잡게 됩니다.\xa03. 주행시\xa0오토삭 장착 주행 시 미끄럼방지 장치(예:ESP, VSC, VDS, ASR 등)는 해제하지 마세요. 제품을 손상시킬 수 있는 급발진, 급제동은 삼가주세요. 또한 이상한 소음이 들리면 일단 차를 멈춘 후 바르게 장착되어 있는지 손상되지 않았는지 확인해 주세요.4. 탈착\xa0사용된 제품은 촉촉하게 젖어있고 더러울 것입니다. 보관 백에 들어있는 장갑을 끼고 커버를 벗긴 후 보관 백에 넣어주시고 집에 돌아와서 물에 행군 후 잘 말립니다. 그리고 다음에 사용할 것에 대비하여 다시 차 트렁크에 넣어두시면 됩니다.\xa0',
#  '먼저 전면유리에 발수코팅제, 물왁스, 합성 세제를 사용하고 있는지, 먼지털이개로 전면유리를 자주 닦지는 않는지 확인해 주세요. 발수코팅제, 왁스 등에 의해 유리 표면에 유막 잔류 및 와이퍼 브레이드를 경화시켜 심한 떨림 및 소음이 발생합니다. 이럴 경우 유막제거제 또는 알코올로 유리면을 깨끗이 닦아낸 후 사용하여 주십시오.\xa0또한 와이퍼 암의 상태(누름앞, 비틀림 등의 규정값 변동)에 따라 떨림 또는 소음이 발생될 수 있습니다. 이 경우에는 와이퍼암을 교체하시거나 가까운 정비소에서 점검을 받으시기 바랍니다.',
#  '먼저 와이퍼 고무표면 및 앞 유리가 오염되어있지 않는지 점검해 주시기 바랍니다. 이럴 경우 이물질 오염이 발생해 닦임 시 줄무늬 발생 및 닦임 성능 저하 발생합니다. 이럴 경우 젖은 타월 또는 세차 면포로 고무날 부위 및 유리 표면의 오염 물질을 제거한 후 사용하여 주십시오.\xa0그리고 잔물주름이 생겼다가 3초 이내에 사라지는 경우는 닦임이 양호한 상태입니다. 또한 조수석 끝단부의 유리곡률이 심한 차종의 경우 끝단부가 다소 뜨는 현상을 보일 수도 있으나 운전자의 시계확보에는 지장이 없습니다.\xa0',
#  '품질보증기간은 판매일로부터 1년이며, 2만km입니다. 단 내비게이션 등 전장제품의 경우 1년이며, 일부 소모용품의 경우는 제외됩니다.',
#  '사용자 편의에 따라 안내 관련 항목 및 탐색 옵션을 설정할 수 있습니다. 자세한 사항은 [제품매뉴얼-내비게이션]을 참조하시기 바랍니다. 또한, 최신 버전이 아닐 경우 지도 및 소프트웨어 업데이트를 진행하여 주시기 바랍니다.',
#  '헤드유닛 [PHONE]키 또는 스티어링 휠의 "☎"키 선택 → 신규기기 등록 기능 선택 → 휴대폰에서 블루투스 기기 검색 후 차량 등록 → 인증번호 입력 또는 인증 팝업 승인 → 블루투스 연결의 순으로 진행할 수 있습니다.자세한 사항은 [제품매뉴얼-블루투스 연결]을 참조하시기 바랍니다.',
#  '헤드유닛 [PHONE] 키를 선택 후 [전화번호부]를 선택합니다. 휴대폰에 저장된 전화번호부 목록을 다운로드 받을 수 있으며, 전화번호를 검색할 수 있습니다. 자세한 사항은 [제품매뉴얼-블루투스 전화]을 참조하시기 바랍니다.추가 질문: 블루투스에는 어떤 기능이 있나요?답변: 휴대폰을 연결하여 음악 청취 및 전화 기능을 사용할 수 있습니다.',
#  'AV 주요 기능에는 라디오(FM/AM) 및 각종 기기 (MP3, USB, iPod 등)를 이용한 음악 청취와 DMB 시청 등이 있으며, 각 모드별 버튼 작동에 관한 자세한 사용 방법은 [제품메뉴얼]을 참조하시기 바랍니다.',
#  '헤드유닛 [설정]키 선택 → [블루링크/UVO]\xa0선택\xa0→ [서비스개통] 선택으로 진행할 수 있습니다. 개통 실패 시 차량 매뉴얼의 현대자동차 또는 기아자동차 고객센터로 문의하여 주시기 바랍니다.블루링크는 안전보안, 차량진단, 원격제어 뿐만 아니라, 스마트폰 연동을 통해 즐겁고 편안한 드라이빙을 지원하는 텔레메틱스 서비스 입니다. 기능 사용 방법에 관련한 자세한 사항은 [제품매뉴얼]을 참조하시기 바랍니다.',
#  '먼저 사용하고 계신 CD가 재생에 적합한지 확인하여 주시기 바랍니다. 일부 디스크 포맷(예-MP4, AAC, VIDEO-CD 등)에 따라 재생을 지원하지 않을 수 있습니다. 이물질이 묻거나 디스크에 긁힘 등의 손상이 발생하지 않도록 관리하여 주시기 바라며, 디스크 삽입구에는 디스크 이외에 다른 물질이 들어가지 않도록 주의하십시오.디스크 취급 시 주의 사항은 [제품매뉴얼 2-8. 디스크에 대하여]를 참조하시기 바랍니다.',
#  '수신 장소에 따라 전파의 세기가 바뀌기도 하고, 장애물에 의해 수신 상태가 나빠질 수 있습니다. 수신 상태가 나빠지면 자동 선국 버튼이나 [SEEK UP/DOWN] 버튼으로 수신상태가 좋은 방송 채널을 선택하여 주십시오. 자동 선국 버튼을 입력 시에 수신 상태가 양호한 주파수를 프리셋(1~12번)에 자동 저장합니다.*Glass ANT(유리 안테나)가 적용되는 차량에는 금속 성분이 함유된 메탈 썬팅지를 부착하면 수신 성능이 매우 저하될 수 있습니다.',
#  '수신 장소에 따라 전파의 세기가 바뀌기도 하고, 장애물에 의해 수신 상태가 나빠질 수 있습니다. 수신 상태가 나빠지면 자동 선국 버튼으로 수신 상태가 좋은 방송 채널을 선택하여 주십시오. 또한 차량에서 사용하는 핸드폰, 블랙박스 등과 같은 전자기기를 사용할 경우 전파방해에 의한 잡음이 발생할 수 있습니다. 차량이 주행 중일 경우 안전상의 이유로 DMB 시청이 불가함을 알려드립니다.',
#  '[제품매뉴얼-고장 증상일 때의 조치 방법]을 참고하시 바라며, 점검 후에도 복구가 되지 않을 경우 [RESET] 버튼을 1초 이상 길게 눌러 시스템을 초기화 하시기 바랍니다. 그런 뒤에도 문제 증상이 사라지지 않으면 가까운 서비스센터를 방문하여 주시기 바랍니다.']
